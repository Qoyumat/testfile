# %% [markdown]
# My Jupyter Notbook on IBM Watson

# %% [markdown]
# Qoyumat Oluwatimilehin Azeez
# Data Analyst

# %% [markdown]
# Data science is the most interesting job in the world. it helps you to connect with everything around you because data is everywhere

# %% [markdown]
# Add all the numbers multiply by three

# %%
(5+7+3)*3
# Out:
# 45

# %% [markdown]
# #create variables
# print(((1 + 3) * (9 - 2) / 2) ** 2)
# (40, 24, 22)
