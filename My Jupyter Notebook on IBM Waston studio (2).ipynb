# %% [markdown]
# # My Jupyter Notbook on IBM Watson studio

# %% [markdown]
# #### Qoyumat Azeez
# Data Analyst

# %% [markdown]
# ###### Data science is the most interesting job in the world. it helps you to connect with everything around you because data is everywhere

# %% [markdown]
# ### Add all the numbers in the parantheses and multiply by three

# %%
(5+7+3)*3
# Out:
# 45

# %% [markdown]
# #create variable
# print(1 + 3) * (9 - 2)
#
# one
# three
# two
# four
# one
# five
